# %% [markdown]
# # 01 — Data exploration
#
# Source: Forbes et al. (2023) dataset, downloaded from OSF on 2026-08-19.
# Goal: understand the file structure before designing the data model.
# *The full dataset showing all symptoms and redundancy coding is available on the Open Science Framework (https://osf.io/r5vqk/).
#
# Questions for this session:
# - What files are there, and in what format?
# - What is one row: a symptom, a diagnosis, or a symptom–diagnosis pair?
# - Which columns identify chapters, diagnoses and symptoms?
# - Any missing values, duplicates or inconsistent labels?

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df = pd.read_xlsx("../data/raw/data_for_suplement.xlsx")

# %%
def dataset_report(df, name="dataset"):
    """Quick structural overview of a dataframe."""
    print(f"=== {name} ===")
    print(f"Shape: {df.shape[0]:,} rows x {df.shape[1]} columns")
    print(f"Duplicate rows: {df.duplicated().sum():,}")
    print(f"Memory: {df.memory_usage(deep=True) .sum() / 1024**2:.2f} MB\n")
    
    summary = pd.DataFrame({
        "dtype": df.dtypes.astype(str),
        "non_null": df.notna() .sum(),
        "nulls": df.isna() .sum(),
        "null_%": (df.isna() .mean() *100) .round(1),
        "unique_%": (df.nunique() / len(df) * 100).round(1),
        "sample": [df[c].dropna().iloc[0] if df[c].notna().any() else None for c in df.columns],
    })
    
    return summary
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#       2
#       3 def dataset_report(df, name="dataset"):
#       4     """Quick structural overview of a dataframe."""
#
# ModuleNotFoundError: No module named 'pandas'
